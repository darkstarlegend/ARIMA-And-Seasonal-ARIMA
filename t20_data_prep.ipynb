# %% [markdown]
# <a href="https://colab.research.google.com/github/darkstarlegend/ARIMA-And-Seasonal-ARIMA/blob/master/t20_data_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

try:
  from yaml import safe_load
except:
  # !pip install pyyaml
  from yaml import safe_load

# %% [markdown]
# Dataset from:
#
# https://www.kaggle.com/datasets/veeralakrishna/cricsheet-a-retrosheet-for-cricket

# %%
"""
from zipfile import ZipFile
with ZipFile("/content/t20s.zip", 'r') as zip:
  zip.extractall(path="/content/data")

"""
# Out:
# '\nfrom zipfile import ZipFile\nwith ZipFile("/content/t20s.zip", \'r\') as zip:\n  zip.extractall(path="/content/data")\n\n'

# %%
filenames=[]
for file in os.listdir('data'):
  filenames.append(os.path.join('data',file))
filenames[0:5]

# %%
final_df=pd.DataFrame()
counter=1

for file in tqdm(filenames):
  with open(file,'r') as f:
    df=pd.json_normalize(safe_load(f))
    df['match_id']=counter
    final_df=final_df.append(df)
    counter+=1

# %%
backup=final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Kuwait', 'deliverie...                0.9
# 0   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Belgium', 'deliveri...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Namibia', 'deliveri...                0.9
#
#    meta.created  meta.revision     info.city    info.dates info.gender  \
# ...

# %%
final_df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.city', 'info.dates', 'info.gender', 'info.match_type',
#        'info.match_type_number', 'info.outcome.winner',
#        'info.outcome.by.wickets', 'info.overs', 'info.teams',
#        'info.toss.decision', 'info.toss.winner', 'info.umpires', 'info.venue',
#        'match_id', 'info.player_of_match', 'info.outcome.by.runs',
#        'info.neutral_venue', 'info.outcome.method', 'info.outcome.result',
#        'info.outcome.eliminator', 'info.supersubs.New Zealand',
#        'info.supersubs.South Africa', 'info.bowl_out',
#        'info.outcome.bowl_out'],
#       dtype='object')

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.bowl_out',
    'info.outcome.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'

],inplace=True)

# %%
final_df.columns
# Out:
# Index(['innings', 'info.city', 'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.winner', 'info.overs', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.umpires', 'info.venue', 'match_id',
#        'info.player_of_match'],
#       dtype='object')

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df=final_df[final_df['info.gender']=='male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# <ipython-input-19-98c7dceffb29>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...     Al Amarat
# 0   [{'1st innings': {'team': 'Kuwait', 'deliverie...     Singapore
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...        London
# 0   [{'1st innings': {'team': 'England', 'deliveri...  Johannesburg
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...           NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...           NaN
# ...

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df=final_df[final_df['info.overs']==20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches =pickle.load(open('dataset_level1.pkl','rb'))

# %%
matches
# Out:
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...     Al Amarat
# 0   [{'1st innings': {'team': 'Kuwait', 'deliverie...     Singapore
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...        London
# 0   [{'1st innings': {'team': 'England', 'deliveri...  Johannesburg
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...           NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...           NaN
# 0   [{'1st innings': {'team': 'Belgium', 'deliveri...   Walferdange
# 0   [{'1st innings': {'team': 'Australia', 'delive...           NaN
# 0   [{'1st innings': {'team': 'Namibia', 'deliveri...         Dubai
#
#       info.dates info.outcome.winner                 info.teams  \
# 0   [2019-10-05]             Ireland     [Ireland, Netherlands]
# ...

# %%
matches.iloc[0]['innings'][0]['1st innings']

# %%
count=1
delivery_df=pd.DataFrame()
for index,row in matches.iterrows():
  if count in [75,108,150,268,360,443,458,584,748,982,1052,1111,1226,1345]:
    count+=1
    continue
  count+=1
  ball_of_match=[]
  batsman=[]
  bowler=[]
  runs=[]
  player_of_dismissed=[]
  teams=[]
  batting_team=[]
  match_id=[]
  city=[]
  venue=[]
  for ball in row['innings'][0]['1st innings']['deliveries']:
    for key in ball.keys():
      match_id.append(count)
      batting_team.append(row['innings'][0]['1st innings']['team'])
      teams.append(row['info.teams'])
      ball_of_match.append(key)
      batsman.append(ball[key]['batsman'])
      bowler.append(ball[key]['bowler'])
      runs.append(ball[key]['runs']['total'])
      city.append(row['info.city'])
      venue.append(row['info.venue'])
      try:
        player_of_dismissed.append(ball[key]['wicket']['player_out'])
      except:
        player_of_dismissed.append(0)
  
  loop_df=pd.DataFrame({
      'match_id':match_id,
      'teams':teams,
      'batting_team':batting_team,
      'ball':ball_of_match,
      'batsman':batsman,
      'bowler':bowler,
      'runs':runs,
      'player_dismmised':player_of_dismissed,
      'city':city,
      'venue':venue
  })
  delivery_df=delivery_df.append(loop_df)

      #for keys in ball.keys():

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball      batsman  \
# 0           2  [Ireland, Netherlands]  Netherlands   0.1     TP Visee
# 1           2  [Ireland, Netherlands]  Netherlands   0.2     TP Visee
# 2           2  [Ireland, Netherlands]  Netherlands   0.3     TP Visee
# 3           2  [Ireland, Netherlands]  Netherlands   0.4    MP O'Dowd
# 4           2  [Ireland, Netherlands]  Netherlands   0.5    MP O'Dowd
# ..        ...                     ...          ...   ...          ...
# 118       964     [Namibia, Scotland]      Namibia  19.2  CG Williams
# 119       964     [Namibia, Scotland]      Namibia  19.3  JN Frylinck
# 120       964     [Namibia, Scotland]      Namibia  19.4     ZE Green
# 121       964     [Namibia, Scotland]      Namibia  19.5     ZE Green
# 122       964     [Namibia, Scotland]      Namibia  19.6     ZE Green
#
#         bowler  runs player_dismmised       city  \
# 0     MR Adair     4                0  Al Amarat
# ...

# %%
def bowl(row):
  for team in row['teams']:
    if team!=row['batting_team']:
      return team

# %%
delivery_df['bowling_team']=delivery_df.apply(bowl,axis=1)

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#      match_id batting_team  ball      batsman     bowler  runs  \
# 0           2  Netherlands   0.1     TP Visee   MR Adair     4
# 1           2  Netherlands   0.2     TP Visee   MR Adair     1
# 2           2  Netherlands   0.3     TP Visee   MR Adair     1
# 3           2  Netherlands   0.4    MP O'Dowd   MR Adair     0
# 4           2  Netherlands   0.5    MP O'Dowd   MR Adair     1
# ..        ...          ...   ...          ...        ...   ...
# 118       964      Namibia  19.2  CG Williams  SM Sharif     0
# 119       964      Namibia  19.3  JN Frylinck  SM Sharif     1
# 120       964      Namibia  19.4     ZE Green  SM Sharif     2
# 121       964      Namibia  19.5     ZE Green  SM Sharif     4
# 122       964      Namibia  19.6     ZE Green  SM Sharif     2
#
#     player_dismmised       city  \
# 0                  0  Al Amarat
# 1                  0  Al Amarat
# 2                  0  Al Amarat
# 3                  0  Al Amarat
# 4                  0  Al Amarat
# ...

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'batting_team', 'ball', 'batsman', 'bowler', 'runs',
#        'player_dismmised', 'city', 'venue', 'bowling_team'],
#       dtype='object')

# %%
#taking top 10 teams and dropping others

# %%
teams=['Australia','India','Bangladesh','New Zealand','South Africa','England','West Indies','Afghanistan','Pakistan','Sri lanka']

# %%
delivery_df=delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df=delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
output=delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismmised','city','venue']]

# %%
output
# Out:
#      match_id batting_team  bowling_team  ball  runs player_dismmised city  \
# 0           4     Pakistan   New Zealand   0.1     0                0  NaN
# 1           4     Pakistan   New Zealand   0.2     0                0  NaN
# 2           4     Pakistan   New Zealand   0.3     0                0  NaN
# 3           4     Pakistan   New Zealand   0.4     0                0  NaN
# 4           4     Pakistan   New Zealand   0.5     0                0  NaN
# ..        ...          ...           ...   ...   ...              ...  ...
# 117       963    Australia  South Africa  19.2     1                0  NaN
# 118       963    Australia  South Africa  19.3     0         JR Hopes  NaN
# 119       963    Australia  South Africa  19.4     1                0  NaN
# 120       963    Australia  South Africa  19.5     0       NW Bracken  NaN
# 121       963    Australia  South Africa  19.6     1                0  NaN
#
#                                    venue
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))
